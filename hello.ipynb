# %%
import pandas as pd
import numpy as np
data = pd.read_csv('phpMYEkMl.csv')

# %%
data.replace('?', np.nan, inplace= True)
data = data.astype({"age": np.float64, "fare": np.float64})

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, axs = plt.subplots(ncols=5, figsize=(30,5))
sns.violinplot(x="survived", y="age", hue="sex", data=data, ax=axs[0])
sns.pointplot(x="sibsp", y="survived", hue="sex", data=data, ax=axs[1])
sns.pointplot(x="parch", y="survived", hue="sex", data=data, ax=axs[2])
sns.pointplot(x="pclass", y="survived", hue="sex", data=data, ax=axs[3])
sns.violinplot(x="survived", y="fare", hue="sex", data=data, ax=axs[4])
# Out:
# <AxesSubplot:xlabel='survived', ylabel='fare'>

# %%
data.replace({'male': 1, 'female': 0}, inplace=True)

# %%
data.corr().abs()[["survived"]]
# Out:
#           survived
# pclass    0.312469
# survived  1.000000
# sex       0.528693
# age       0.055513
# sibsp     0.027825
# parch     0.082660
# fare      0.244265

# %%
data['relatives'] = data.apply (lambda row: int((row['sibsp'] + row['parch']) > 0), axis=1)
data.corr().abs()[["survived"]]
# Out:
#            survived
# pclass     0.312469
# survived   1.000000
# sex        0.528693
# age        0.055513
# sibsp      0.027825
# parch      0.082660
# fare       0.244265
# relatives  0.201719

# %%
data = data[['sex', 'pclass','age','relatives','fare','survived']].dropna()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(data[['sex','pclass','age','relatives','fare']], data.survived, test_size=0.2, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(x_train)
X_test = sc.transform(x_test)

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
from sklearn import metrics
predict_test = model.predict(X_test)
print(metrics.accuracy_score(y_test, predict_test))
# Out:
# 0.7464114832535885

# %%
from keras.models import Sequential
from keras.layers import Dense

model = Sequential()

# %%
model.add(Dense(5, kernel_initializer = 'uniform', activation = 'relu', input_dim = 5))
model.add(Dense(5, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dense(1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 5)                 30
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 30
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 6
# =================================================================
# Total params: 66
# Trainable params: 66
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer="adam", loss='binary_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, batch_size=32, epochs=50)
# Out:
# Epoch 1/50
# 27/27 [==============================] - 0s 592us/step - loss: 0.6923 - accuracy: 0.5813
# Epoch 2/50
# 27/27 [==============================] - 0s 592us/step - loss: 0.6899 - accuracy: 0.5861
# Epoch 3/50
# 27/27 [==============================] - 0s 629us/step - loss: 0.6854 - accuracy: 0.5873
# Epoch 4/50
# 27/27 [==============================] - 0s 925us/step - loss: 0.6759 - accuracy: 0.6974
# Epoch 5/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.6592 - accuracy: 0.7751
# Epoch 6/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.6361 - accuracy: 0.7679
# Epoch 7/50
# 27/27 [==============================] - 0s 851us/step - loss: 0.6071 - accuracy: 0.7715
# Epoch 8/50
# 27/27 [==============================] - 0s 962us/step - loss: 0.5772 - accuracy: 0.7727
# Epoch 9/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.5490 - accuracy: 0.7727
# Epoch 10/50
# 27/27 [==============================] - 0s 814us/step - loss: 0.5270 - accuracy: 0.7727
# Epoch 11/50
# 27/27 [==============================] - 0s 925us/step - loss: 0.5082 - accuracy: 0.7739
# Epoch 12/50
# 27/27 [==============================] - 0s 777us/step - loss: 0.4956 - accuracy: 0.7715
# Epoch 13/50
# 27/27 [==============================] - 0s 629us/step - loss: 0.4860 - accuracy: 0.7727
# Epoch 14/50
# 27/27 [==============================] - 0s 629us/step - loss: 0.4780 - accuracy: 0.7763
# Epoch 15/50
# 27/27 [==============================] - 0s 666us/step - loss: 0.4721 - accuracy: 0.7811
# Epoch 16/50
# 27/27 [==============================] - 0s 666us/step - loss: 0.4681 - accuracy: 0.7835
# Epoch 17/50
# 27/27 [==============================] - 0s 629us/step - loss: 0.4655 - accuracy: 0.7835
# Epoch 18/50
# 27/27 [==============================] - 0s 703us/step - loss: 0.4634 - accuracy: 0.7823
# Epoch 19/50
# 27/27 [==============================] - 0s 629us/step - loss: 0.4615 - accuracy: 0.7835
# Epoch 20/50
# 27/27 [==============================] - 0s 629us/step - loss: 0.4600 - accuracy: 0.7823
# Epoch 21/50
# 27/27 [==============================] - 0s 666us/step - loss: 0.4587 - accuracy: 0.7835
# Epoch 22/50
# 27/27 [==============================] - 0s 740us/step - loss: 0.4578 - accuracy: 0.7823
# Epoch 23/50
# 27/27 [==============================] - 0s 703us/step - loss: 0.4574 - accuracy: 0.7823
# Epoch 24/50
# 27/27 [==============================] - 0s 629us/step - loss: 0.4566 - accuracy: 0.7847
# Epoch 25/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4554 - accuracy: 0.7859
# Epoch 26/50
# 27/27 [==============================] - 0s 925us/step - loss: 0.4553 - accuracy: 0.7787
# Epoch 27/50
# 27/27 [==============================] - 0s 777us/step - loss: 0.4542 - accuracy: 0.7847
# Epoch 28/50
# 27/27 [==============================] - 0s 1ms/step - loss: 0.4537 - accuracy: 0.7823
# Epoch 29/50
# 27/27 [==============================] - 0s 703us/step - loss: 0.4531 - accuracy: 0.7847
# Epoch 30/50
# 27/27 [==============================] - 0s 629us/step - loss: 0.4526 - accuracy: 0.7847
# Epoch 31/50
# 27/27 [==============================] - 0s 592us/step - loss: 0.4523 - accuracy: 0.7823
# Epoch 32/50
# 27/27 [==============================] - 0s 629us/step - loss: 0.4518 - accuracy: 0.7847
# Epoch 33/50
# 27/27 [==============================] - 0s 703us/step - loss: 0.4518 - accuracy: 0.7859
# Epoch 34/50
# 27/27 [==============================] - 0s 592us/step - loss: 0.4514 - accuracy: 0.7847
# Epoch 35/50
# 27/27 [==============================] - 0s 629us/step - loss: 0.4513 - accuracy: 0.7883
# Epoch 36/50
# 27/27 [==============================] - 0s 777us/step - loss: 0.4516 - accuracy: 0.7883
# Epoch 37/50
# 27/27 [==============================] - 0s 851us/step - loss: 0.4506 - accuracy: 0.7871
# Epoch 38/50
# 27/27 [==============================] - 0s 740us/step - loss: 0.4502 - accuracy: 0.7811
# Epoch 39/50
# 27/27 [==============================] - 0s 888us/step - loss: 0.4501 - accuracy: 0.7859
# Epoch 40/50
# 27/27 [==============================] - 0s 888us/step - loss: 0.4495 - accuracy: 0.7871
# Epoch 41/50
# 27/27 [==============================] - 0s 740us/step - loss: 0.4493 - accuracy: 0.7859
# Epoch 42/50
# 27/27 [==============================] - 0s 777us/step - loss: 0.4490 - accuracy: 0.7859
# Epoch 43/50
# 27/27 [==============================] - 0s 703us/step - loss: 0.4488 - accuracy: 0.7811
# Epoch 44/50
# 27/27 [==============================] - 0s 777us/step - loss: 0.4485 - accuracy: 0.7823
# Epoch 45/50
# 27/27 [==============================] - 0s 629us/step - loss: 0.4484 - accuracy: 0.7847
# Epoch 46/50
# 27/27 [==============================] - 0s 629us/step - loss: 0.4485 - accuracy: 0.7835
# Epoch 47/50
# 27/27 [==============================] - 0s 629us/step - loss: 0.4481 - accuracy: 0.7883
# Epoch 48/50
# 27/27 [==============================] - 0s 666us/step - loss: 0.4476 - accuracy: 0.7859
# Epoch 49/50
# 27/27 [==============================] - 0s 666us/step - loss: 0.4474 - accuracy: 0.7859
# Epoch 50/50
# 27/27 [==============================] - 0s 666us/step - loss: 0.4477 - accuracy: 0.7835

# %%
y_pred = model.predict_classes(X_test)
print(metrics.accuracy_score(y_test, y_pred))
# Out:
# 0.7894736842105263
